# %%
import pandas as pd
import cpi
import nasdaqdatalink
import datetime as dt

# %%
inflation_rate = []
cpi_values = []
datetime_values = []


years = 22
#subtract by years + 1 because we need annual inflation by grabbing the year before's values
start_year = dt.date.today().year - (years+1)
reset_months = 1
months =  ( (years + 1) * 12) + (dt.date.today().month-1)

for i in range(months):
    
    if reset_months > 12: 
        reset_months = 1
        start_year +=1
        
    datetime_values.append(dt.date(start_year, reset_months, 1))
    
    cpi_data = cpi.get(dt.date(start_year, reset_months, 1))
    cpi_values.append(cpi_data)
     
    reset_months += 1
    
    if i >= 12:
        inflation = (cpi_values[i] - cpi_values[i-12]) / cpi_values[i-12]
        inflation_rate.append(inflation)

datetime_values = datetime_values[12:]
  
inflation_df = pd.DataFrame(data = {"Inflation Rate": inflation_rate}, index = datetime_values)  
inflation_df["Inflation Percent Change"] = inflation_df["Inflation Rate"].pct_change()
inflation_df
# Out:
#             Inflation Rate  Inflation Percent Change
# 2000-01-01        0.027389                       NaN
# 2000-02-01        0.032219                  0.176346
# 2000-03-01        0.037576                  0.166266
# 2000-04-01        0.030686                 -0.183359
# 2000-05-01        0.031889                  0.039216
# ...                    ...                       ...
# 2021-09-01        0.053903                  0.026484
# 2021-10-01        0.062219                  0.154261
# 2021-11-01        0.068090                  0.094366
# 2021-12-01        0.070364                  0.033397
# 2022-01-01        0.074799                  0.063025
#
# [265 rows x 2 columns]

# %%
#put in a seperate cell to avoid reaching api call limits
usa_gdp = nasdaqdatalink.get("FRED/GDP")
usa_gdp = usa_gdp/1000

# %%
start_year = dt.date.today().year - 22

usa_gdp = usa_gdp.reset_index()


for i in range(len(usa_gdp)):
    entry_year = usa_gdp.iloc[i,0].date().year
    if entry_year == start_year:
        usa_gdp = usa_gdp[i:]
        break

usa_gdp = usa_gdp.set_index("Date")
usa_gdp.rename(columns = {"Value": "USA GDP in Trillions"}, inplace = True)
usa_gdp["GDP Percent Change"] = usa_gdp["USA GDP in Trillions"]

usa_gdp
# Out:
# ---------------------------------------------------------------------------
# DataLinkError                             Traceback (most recent call last)
# <ipython-input-5-6c818ad8bd61> in <module>
# ----> 1 usa_gdp = nasdaqdatalink.get("FRED/GDP")
#       2 usa_gdp = usa_gdp/1000
#       3
#       4 start_year = dt.date.today().year - 22
#       5
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\connection.py in request(cls, http_verb, url, **options)
#      37         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      38
# ---> 39         return cls.execute_request(http_verb, abs_url, **options)
#      40
#      41     @classmethod
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\connection.py in execute_request(cls, http_verb, url, **options)
#      49                                        **options)
#      50             if response.status_code < 200 or response.status_code >= 300:
# ---> 51                 cls.handle_api_error(response)
#      52             else:
#      53                 return response
#
# ~\anaconda3\envs\dev\lib\site-packages\nasdaqdatalink\connection.py in handle_api_error(cls, resp)
#      94         # throw generic error
#      95         if 'error' not in error_body:
# ---> 96             raise DataLinkError(http_status=resp.status_code, http_body=resp.text)
#      97
#      98         code = error_body['error']['code']
#
# DataLinkError: (Status 429) Something went wrong. Please try again. If you continue to have problems, please contact us at connect@data.nasdaq.com.

# %%
combined_df = pd.concat(inflation_df, usa_gdp)
# Out:
#           Date      Value
# 212 2000-01-01  10.002179
# 213 2000-04-01  10.247720
# 214 2000-07-01  10.318165
# 215 2000-10-01  10.435744
# 216 2001-01-01  10.470231
# ..         ...        ...
# 295 2020-10-01  21.477597
# 296 2021-01-01  22.038226
# 297 2021-04-01  22.740959
# 298 2021-07-01  23.202344
# 299 2021-10-01  23.992355
#
# [88 rows x 2 columns]
